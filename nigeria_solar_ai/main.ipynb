# %% [markdown]
# # Nigeria Solar AI - Data Fetching, Training, and Evaluation
# This notebook contains the complete pipeline for the Nigeria Solar Energy predictor.

# %%
from fetch_data import fetch_nasa_power_data
# Uncomment below to fetch data for the first time
# fetch_nasa_power_data()

# %%
from train_models import train_and_eval
# Uncomment below to run preprocessing, train the ANN, CNN, and LSTM, and dump scaler weights
# train_and_eval()
